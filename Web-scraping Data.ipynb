# %% [markdown]
# # Web-Scraping data using BeautifulSoup
# ### By: Anas Puthawala

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# page = 1
# while page != 9:
#     url = f'https://deepmind.com/blog?page={page}'
#     page += 1

# %%
url = 'https://deepmind.com/blog?page=1'
html_source = requests.get(url).text

# using BeautifulSoup
soup = BeautifulSoup(html_source, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="loading" dir="ltr" lang="ALL">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>\n  <base href="/"/>\n  <!-- Facebook base meta tags. -->\n  <meta content="600" property="og:image:width"/>\n  <meta content="600" property="og:image:height"/>\n  <meta content="Deepmind" property="og:site_name"/>\n  <meta content="website" property="og:type"/>\n  <!-- Twitter base meta tags. -->\n  <meta content="summary_large_image" name="twitter:card"/>\n  <meta content="@DeepMindAI" name="twitter:creator"/>\n  <!-- Set in Angular. -->\n  <title>\n   Blog | DeepMind\n  </title>\n  <meta content="Read the latest articles and stories from DeepMind and find out more about our latest breakthroughs in cutting-edge AI research." name="description"/>\n  <link href="https://lh3.googleusercontent.com" rel="preconnect"/>\n  <link href="assets/favicon.ico" rel="icon"/>\n  <link href="styles.4ac422d2d6faf63ca7fa.css" rel="stylesheet"/>\n  <style ng-transition="deepmind-website">\n   [_nghost-sc0] {\n  display: flex;\n  flex-direction: column;\n}\n@media (min-width: 1024px) {\n  [_nghost-sc0] {\n    flex-direction: row;\n  }\n}\n[_nghost-sc0]   .dm-body[_ngcontent-sc0] {\n  background-color: #f0f5f5;\n  height: 100%;\n  overflow-x: hidden;\n  width: 100%;\n}\n@media (min-width: 1024px) {\n  [_nghost-sc0]   .dm-body[_ngcontent-sc0] {\n    width: calc(100% - 100px);\n  }\n}\n[_nghost-sc0]   .svg-elements[_ngcontent-sc0] {\n  height: 0;\n  position: absolute;\n  visibility: hidden;\n  width: 0;\n}\n  </style>\n  <style ng-transition="deepmind-website">\n   [_nghost-sc2] {\n  display: block;\n  position: relative;\n}\nheader[_ngcontent-sc2] {\n  background-color: #0053d6;\n  height: 60px;\n  width: 100%;\n}\n@media (min-width: 768px) {\n  header[_ngcontent-sc2] {\n    height: 70px;\n  }\n}\n@media (min-width: 1024px) {\n  header[_ngcontent-sc2] {\n    height: 100%;\n    width: 100px;\n  }\n}\nheader[_ngcontent-sc2]::after {\n  background-color: #0053d6;\n  content: "";\n  height: 100%;\n  position: absolute;\n  right: 0;\n  top: 0;\n  transition: right 0.3s ease, width 0.3s ease;\n  width: 0;\n  z-index: 34;\n}\nheader.is-peaking[_ngcontent-sc2]::after {\n  right: -10px;\n  width: 10px;\n}\n.header-container[_ngcontent-sc2] {\n  background-color: #0053d6;\n  display: flex;\n  flex-direction: column;\n  height: inherit;\n  justify-content: space-between;\n  left: 0;\n  padding: 0 20px;\n  position: fixed;\n  top: 0;\n  width: inherit;\n  z-index: 35;\n}\n@media (min-width: 1024px) {\n  .header-container[_ngcontent-sc2] {\n    height: 100%;\n    padding: 30px 20px;\n  }\n}\nheader.is-menu-open[_ngcontent-sc2]   .header-container[_ngcontent-sc2] {\n  width: 100%;\n}\n@media (min-width: 1024px) {\n  header.is-menu-open[_ngcontent-sc2]   .header-container[_ngcontent-sc2] {\n    width: 100px;\n  }\n}\n.header-container[_ngcontent-sc2]   ul[_ngcontent-sc2] {\n  list-style: none;\n  margin: 0;\n  padding: 0;\n}\n.menu-wrapper[_ngcontent-sc2] {\n  display: flex;\n  height: 100%;\n}\n@media (min-width: 1024px) {\n  .menu-wrapper[_ngcontent-sc2] {\n    flex-direction: column;\n    height: auto;\n  }\n}\n.menu-header[_ngcontent-sc2] {\n  align-items: center;\n  display: flex;\n  justify-content: space-between;\n  width: 100%;\n}\n@media (min-width: 1024px) {\n  .menu-header[_ngcontent-sc2] {\n    display: block;\n  }\n}\n.menu-header[_ngcontent-sc2]   .logo[_ngcontent-sc2] {\n  display: block;\n  margin: 0 0 0 -12px;\n}\n@media (min-width: 768px) {\n  .menu-header[_ngcontent-sc2]   .logo[_ngcontent-sc2] {\n    margin: 0;\n  }\n}\n@media (min-width: 1024px) {\n  .menu-header[_ngcontent-sc2]   .logo[_ngcontent-sc2] {\n    margin: 0 0 30px;\n  }\n}\n.menu-header[_ngcontent-sc2]   .logo[_ngcontent-sc2]   svg[_ngcontent-sc2] {\n  display: block;\n  height: 40px;\n  width: 184px;\n}\n@media (min-width: 1024px) {\n  .menu-header[_ngcontent-sc2]   .logo[_ngcontent-sc2]   svg[ ...

# %%
res = 'content-card-body'

match = soup.find_all('div', class_=res)

#Loop through match and find all seperate sections ('content') and get the title
titlelist = []
for content in match:
    title = content.find('a') 
    titlelist.append(title.text.strip())
titlelist
# Out:
# ['Language modelling at scale',
#  'Exploring the beauty of pure mathematics in novel ways',
#  'Real-World Challenges for AGI',
#  'Opening up a physics simulator for robotics',
#  'Stacking our way to more general robots',
#  'Predicting gene expression with AI',
#  'Nowcasting',
#  'Building architectures that can handle the world’s data',
#  'Generally capable agents emerge from open-ended play',
#  'Putting the power of AlphaFold into the world’s hands',
#  'An update on our racial justice efforts',
#  'Advancing sports analytics through AI research',
#  'Game theory as an engine for large-scale data analysis',
#  'MuZero: Mastering Go, chess, shogi and Atari without rules',
#  'Using JAX to accelerate our research',
#  'AlphaFold: a solution to a 50-year-old grand challenge in biology',
#  'Breaking down global barriers to access',
#  'FermiNets: Quantum Physics and Chemistry from First Principles',
#  'Fast reinforcement learning through the composition of behaviours',
#  'Traffic prediction with advanced Graph Neural Networks']

# %%
# Next let's get the summaries
summarylist = []
for content in match:
    summary = content.find('p', class_ = 'medium')
    summarylist.append(summary.text.strip())
    
summarylist
# Out:
# ['We are releasing three papers on language models, Gopher, ethical considerations, and retrieval.',
#  'Discovering new patterns in the fields of topology and representation theory with machine learning',
#  'Koray Kavukcuoglu, VP of Research, discusses why addressing real-world challenges now helps advance the development of...',
#  "As part of DeepMind's mission of advancing science, we have acquired the MuJoCo physics simulator and are making it...",
#  'Introducing RGB-Stacking as a new benchmark for vision-based robotic manipulation.',
#  'Our new Enformer architecture advances genetic research by improving the ability to predict how DNA sequence influences...',
#  'Our latest research and state-of-the-art model advances the science of Precipitation Nowcasting.',
#  'Perceiver IO, a more general version of the Perceiver architecture, can produce a wide variety of outputs from many...',
#  'In new work, algorithmic advances and new training environments lead to agents which exhibit general heuristic...',
#  'In partnership with EMBL-EBI, we’re incredibly proud to be launching the AlphaFold Protein Structure Database.',
#  "To help combat racism and advance racial equity, we've made donations to organisations that support Black communities in...",
#  'Sports analytics is in the midst of a remarkably important era, offering interesting opportunities for AI researchers...',
#  'Our research explored a new approach to an old problem: we reformulated principal component analysis (PCA), a type of...',
#  'Planning winning strategies in unknown environments is a step forward in the pursuit of general-purpose algorithms.',
#  'An introduction to our JAX ecosystem and why we find it useful for our AI research.',
#  'In a major scientific advance, AlphaFold\xa0is recognised as a solution to the protein folding problem.',
#  "We're expanding our scholars programme to support more countries currently underrepresented in AI.",
#  'We’ve developed a new neural network architecture, the Fermionic Neural Network or FermiNet, which is well-suited to...',
#  'The combination of reinforcement learning and deep learning has led to impressive results, such as agents that can learn...',
#  'Working with our partners at Google Maps, we used advanced machine learning techniques including Graph Neural Networks,...']

# %%
# Let's also get the date of the publication while we're at it
dates = []
for content in match:
    footer = content.find('div', class_='footer') #Find the footer
    
    dates.append(footer.find('p').text.strip()) #Append the dates that are being scraped from the footer
dates
# Out:
# ['08 Dec 2021',
#  '01 Dec 2021',
#  '02 Nov 2021',
#  '18 Oct 2021',
#  '11 Oct 2021',
#  '04 Oct 2021',
#  '29 Sep 2021',
#  '03 Aug 2021',
#  '27 Jul 2021',
#  '22 Jul 2021',
#  '04 Jun 2021',
#  '07 May 2021',
#  '06 May 2021',
#  '23 Dec 2020',
#  '04 Dec 2020',
#  '30 Nov 2020',
#  '05 Nov 2020',
#  '19 Oct 2020',
#  '12 Oct 2020',
#  '03 Sep 2020']

# %%
#Last but not least, let's see if it was a 'Research' article
researchlist = []
for content in match:
    header = content.find('div', class_=['header', 'category']) #Header
    researchlist.append(header.find_all('p', class_="caption")[-1].text.strip()) # Append to researchlist, the 'type' of article
    
researchlist
# Out:
# ['Research',
#  'Research',
#  '',
#  'News',
#  'Research',
#  'Research',
#  '',
#  '',
#  'Research',
#  'Research',
#  'News',
#  '',
#  '',
#  '',
#  '',
#  'Research',
#  '',
#  'Research',
#  '',
#  'Research']

# %% [markdown]
# ## Sculpting the DataFrame

# %% [markdown]
# Now that we have the title, the summaries, the dates, and the type of article it is let's throw it all into a Pandas DataFrame and output a CSV file at the end of it all

# %%
df = pd.DataFrame(list(zip(titlelist, summarylist, dates, researchlist)), columns = ['Title', 'Summary', 'Date', 'Type of Article'])
df
# Out:
#                                                 Title  \
# 0                         Language modelling at scale
# 1   Exploring the beauty of pure mathematics in no...
# 2                       Real-World Challenges for AGI
# 3         Opening up a physics simulator for robotics
# 4             Stacking our way to more general robots
# 5                  Predicting gene expression with AI
# 6                                          Nowcasting
# 7   Building architectures that can handle the wor...
# 8   Generally capable agents emerge from open-ende...
# 9   Putting the power of AlphaFold into the world’...
# 10            An update on our racial justice efforts
# 11     Advancing sports analytics through AI research
# 12  Game theory as an engine for large-scale data ...
# 13  MuZero: Mastering Go, chess, shogi and Atari w...
# 14               Using JAX to accelerate our research
# 15  AlphaFold: a solution to a 50-year-old grand c...
# 16            Breaking down global barriers to access
# 17  FermiNets: Quantum Physics and Chemistry from ...
# 18  Fast reinforcement learning through the compos...
# 19  Traffic prediction with advanced Graph Neural ...
#
#                                               Summary         Date  \
# 0   We are releasing three papers on language mode...  08 Dec 2021
# 1   Discovering new patterns in the fields of topo...  01 Dec 2021
# 2   Koray Kavukcuoglu, VP of Research, discusses w...  02 Nov 2021
# 3   As part of DeepMind's mission of advancing sci...  18 Oct 2021
# 4   Introducing RGB-Stacking as a new benchmark fo...  11 Oct 2021
# 5   Our new Enformer architecture advances genetic...  04 Oct 2021
# 6   Our latest research and state-of-the-art model...  29 Sep 2021
# 7   Perceiver IO, a more general version of the Pe...  03 Aug 2021
# 8   In new work, algorithmic advances and new trai...  27 Jul 2021
# 9   In partnership with EMBL-EBI, we’re incredibly...  22 Jul 2021
# 10  To help combat racism and advance racial equit...  04 Jun 2021
# 11  Sports analytics is in the midst of a remarkab...  07 May 2021
# 12  Our research explored a new approach to an old...  06 May 2021
# 13  Planning winning strategies in unknown environ...  23 Dec 2020
# 14  An introduction to our JAX ecosystem and why w...  04 Dec 2020
# 15  In a major scientific advance, AlphaFold is re...  30 Nov 2020
# 16  We're expanding our scholars programme to supp...  05 Nov 2020
# 17  We’ve developed a new neural network architect...  19 Oct 2020
# 18  The combination of reinforcement learning and ...  12 Oct 2020
# 19  Working with our partners at Google Maps, we u...  03 Sep 2020
#
#    Type of Article
# 0         Research
# 1         Research
# 2
# 3             News
# 4         Research
# 5         Research
# 6
# 7
# 8         Research
# 9         Research
# 10            News
# 11
# 12
# 13
# 14
# 15        Research
# 16
# 17        Research
# 18
# 19        Research

# %%
# Output it as a excel file

filename = 'deepmind_webscrape.xlsx'
df.to_excel(filename)
