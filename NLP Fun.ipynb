# %% [markdown]
# Introduction to NLP. This notebook touches on five major points involved in the realm of NLP.
# 1. First we will web-scrape the data
# 2. We'll tokenize the data and remove stop words
# 3. We'll experiment with stemming (various stemmers such as Porter / Lancaster) and Lemmatization
# 4. We can experiment with POS tagging and Named Entity Recognition
#
# By Anas Puthawala

# %% [markdown]
# # Web-scraping data

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://9to5mac.com/2021/07/19/man-behind-linkedin-scraping/'
html_source = requests.get(url).text
html_source
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n\t<head>\n\t\t\t\t<meta charset="UTF-8" />\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1.0, minimal-ui">\n\t\t\t\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<!-- Jetpack Site Verification Tags -->\n<meta name="google-site-verification" content="DzsUrmZ9ZlyfaPuXpOlNS3LpML0I6aZl89iaB86c9v8" />\n<meta name="msvalidate.01" content="808CE29E29F1230249D24A893DE871FB" />\n<meta name="p:domain_verify" content="e6250102e52a4d42f3964f1974e77e52" />\n<meta name="yandex-verification" content="97441597b112e146" />\n\t\t<script>\n\t\t\twindow.dataLayer = window.dataLayer || [];\n\t\t\t\t\t\tdataLayer.push({"pageType":"post","postCategory":["facebook","linkedin","privacy","security"]});\n\t\t\t\t\t</script>\n\t\t\t\t<script src="https://9to5mac.com/wp-content/themes/9to5-2015/assets/js/adsbygoogle.js"></script>\n\n               <!-- Google Tag Manager -->\n\t\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\t\t\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\t\t\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\t\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-M48W9J\');</script>\n\t\t<!-- End Google Tag Manager -->\n\t\t\t\t\t<link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\n\t\t<link rel="apple-touch-icon" href="/apple-touch-icon.png" />\n\t\t<link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png" />\n\t\t<link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png" />\n\t\t<link rel="apple-touch-icon" sizes="76x76" href="/apple-touch-icon-76x76.png" />\n\t\t<link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png" />\n\t\t<link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png" />\n\t\t<link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png" />\n\t\t<link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png" />\n\t\t<link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon-180x180.png" />\n\t\t<link rel="icon" sizes="192x192" href="/wp-content/themes/9to5-2015/images/favicons/9to5mac/icon-192x192.png">\n\t\t<link rel="manifest" href="/wp-content/themes/9to5-2015/images/favicons/9to5mac/site.webmanifest">\n\t\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v16.7 (Yoast SEO v16.7) - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>LinkedIn scraping of 700M records was &#039;for fun&#039; says hacker - 9to5Mac</title>\n\t<meta name="description" content="We last month reported a LinkedIn scraping that exposed the data of 700 million users – some 92% of all those on the service. The data ..." />\n\t<link rel="canonical" href="https://9to5mac.com/2021/07/19/man-behind-linkedin-scraping/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Man behind LinkedIn scraping said he grabbed 700M profiles &#039;for fun&#039;" />\n\t<meta property="og:description" content="We last month reported a LinkedIn scraping that exposed the data of 700 million users – some 92% of all those on the service. The data ..." />\n\t<meta property="og:url" content="https://9to5mac.com/2021/07/19/man-behind-linkedin-scraping/" />\n\t<meta property="og:site_name" content="9to5Mac" />\n\t<meta property="article:publisher" content="https://www.facebook.com/pages/9to5Maccom/110423472290" />\n\t<meta property="article:published_time" content="2021-07-19T12:12:37+00:00" />\n\t<meta property="article:modified_time" content="2021-07-19T12:12:39+00:00" />\n\t<meta property="og:image" content="https://i1.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/07/LinkedIn-scraping.j ...

# %%
soup = BeautifulSoup(html_source, 'html')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, minimal-ui" name="viewport"/>\n  <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>\n  <!-- Jetpack Site Verification Tags -->\n  <meta content="DzsUrmZ9ZlyfaPuXpOlNS3LpML0I6aZl89iaB86c9v8" name="google-site-verification"/>\n  <meta content="808CE29E29F1230249D24A893DE871FB" name="msvalidate.01"/>\n  <meta content="e6250102e52a4d42f3964f1974e77e52" name="p:domain_verify"/>\n  <meta content="97441597b112e146" name="yandex-verification"/>\n  <script>\n   window.dataLayer = window.dataLayer || [];\n\t\t\t\t\t\tdataLayer.push({"pageType":"post","postCategory":["facebook","linkedin","privacy","security"]});\n  </script>\n  <script src="https://9to5mac.com/wp-content/themes/9to5-2015/assets/js/adsbygoogle.js">\n  </script>\n  <!-- Google Tag Manager -->\n  <script>\n   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\t\t\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\t\t\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\t\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-M48W9J\');\n  </script>\n  <!-- End Google Tag Manager -->\n  <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n  <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>\n  <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n  <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n  <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n  <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>\n  <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>\n  <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="/wp-content/themes/9to5-2015/images/favicons/9to5mac/icon-192x192.png" rel="icon" sizes="192x192"/>\n  <link href="/wp-content/themes/9to5-2015/images/favicons/9to5mac/site.webmanifest" rel="manifest"/>\n  <!-- This site is optimized with the Yoast SEO Premium plugin v16.7 (Yoast SEO v16.7) - https://yoast.com/wordpress/plugins/seo/ -->\n  <title>\n   LinkedIn scraping of 700M records was \'for fun\' says hacker - 9to5Mac\n  </title>\n  <meta content="We last month reported a LinkedIn scraping that exposed the data of 700 million users – some 92% of all those on the service. The data ..." name="description"/>\n  <link href="https://9to5mac.com/2021/07/19/man-behind-linkedin-scraping/" rel="canonical"/>\n  <meta content="en_US" property="og:locale"/>\n  <meta content="article" property="og:type"/>\n  <meta content="Man behind LinkedIn scraping said he grabbed 700M profiles \'for fun\'" property="og:title"/>\n  <meta content="We last month reported a LinkedIn scraping that exposed the data of 700 million users – some 92% of all those on the service. The data ..." property="og:description"/>\n  <meta content="https://9to5mac.com/2021/07/19/man-behind-linkedin-scraping/" property="og:url"/>\n  <meta content="9to5Mac" property="og:site_name"/>\n  <meta content="https://www.facebook.com/pages/9to5Maccom/110423472290" property="article:publisher"/>\n  <meta content="2021-07-19T12:12:37+00:00" property="article:published_time"/>\n  <meta content="2021-07-19T12:12:39+00:00" property="article:modified_time"/>\n  <meta content="https://i1.wp.com/9to5mac.com/wp-content/uploads/sites/6/2021/07/LinkedIn-scraping.jpg?resize=1200%2C628&amp;quality=82&amp;strip=all&amp;ssl=1" property="og:image"/>\n  <meta content="3000" property="og ...

# %%
class_name = 'post-body'
match = soup.find('div', class_=class_name)
print(match.text)
# Out:
# Last month we reported a LinkedIn scraping that exposed the data of 700 million users – some 92% of all those on the service. The data included location, phone numbers, and inferred salaries.
# The man behind it has now been identified, and says that he did it “for fun” – though he is also selling the data …
#
#
# Background
# Data scraping is a controversial topic. At its simplest, it means writing a piece of software to visit a webpage, read the data displayed, and then add it to a database.
# More commonly, people will use APIs (application programming interfaces) provided by the web service for legitimate purposes, and use it to grab large quantities of data.
# It’s controversial because, on the one hand, those doing the scraping can argue that they are only accessing publicly available data – they are simply doing so in an efficient way. Others argue that they are abusing tools not intended for the purpose, and that there is more data available through APIs than is visible on websites, making it hard for users to know what data has been exposed.
# There’s even controversy over terminology. Many security professionals argue that it isn’t a security breach if the data is available for public access. I would argue that if a service like LinkedIn doesn’t spot someone scraping literally hundreds of millions of records, that’s a massive security failing.
# LinkedIn scraping for fun – and profit
# BBC News spoke with the man who took the data, under the name Tom Liner.
#
# How would you feel if all your information was catalogued by a hacker and put into a monster spreadsheet with millions of entries, to be sold online to the highest paying cyber-criminal?
# That’s what a hacker calling himself Tom Liner did last month “for fun” when he compiled a database of 700 million LinkedIn users from all over the world, which he is selling for around $5,000 (£3,600; €4,200) […]
# In the case of Mr Liner, his latest exploit was announced at 08:57 BST in a post on a notorious hacking forum […] “Hi, I have 700 million 2021 LinkedIn records”, he wrote. Included in the post was a link to a sample of a million records and an invite for other hackers to contact him privately and make him offers for his database.
#
# Liner says he was also behind the scraping of 533M Facebook profiles back in April (you can check whether your data was grabbed).
#
# Tom told me he created the 700 million LinkedIn database using “almost the exact same technique” that he used to create the Facebook list.
# He said: “It took me several months to do. It was very complex. I had to hack the API of LinkedIn. If you do too many requests for user data in one time then the system will permanently ban you.”
#
# LinkedIn denies that Liner used its API, but cybersecurity company SIS Intelligence says we need more controls over their use.
#
# CEO Amir Hadžipašić says the details in this, and other mass-scraping events, are not what most people would expect to be available in the public domain. He thinks API programmes, which give more information about users than the general public can see, should be more tightly controlled.
# “Large-scale leaks like this are concerning, given the intricate detail, in some cases, of this information – such as geographic locations or private mobile and email addresses.
# “To most people it will come as a surprise that there’s so much information held by these API enrichment services.
#
# Security expert and haveibeenpwned.com owner Troy Hunt says he doesn’t consider API misuse to be a security breach, but mostly agrees on the need for more control.
#
# “I don’t disagree with the stance of Facebook and others but I feel that the response of ‘this isn’t a problem’ is, whilst possibly technically accurate, missing the sentiment of how valuable this user data is and their perhaps downplaying their own roles in the creation of these databases.”
#
# Photo: Benjamin Lehman/Unsplash
# FTC: We use income earning auto affiliate links. More.
# Check out 9to5Mac on YouTube for more Apple news:

# %% [markdown]
# # Tokenize the data

# %%
from nltk.tokenize import word_tokenize

# %%
tok = word_tokenize(match.text)

# %%
len(tok)
# Out:
# 796

# %% [markdown]
# ### Lowercase and Removing stop-words

# %%
from nltk.corpus import stopwords

# %%
#lowercase
tok = [str.lower(i) for i in tok]

# %%
stopwords = set(stopwords.words('english'))

# %%
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
import string

# %%
filt_tok = [word for word in tok if word not in stopwords]
print(f'The length of the new filtered token with stopwords removed is: {len(filt_tok)}')

#Removing punctuation

punctuations = string.punctuation + '–' + '…' + '“'
# for char in filt_tok:
#     if char in punctuations:
#         del
filt_tok_2 = []
for char in filt_tok:
    if char not in punctuations:
#         print(char)
        filt_tok_2.append(char)
    
print(f'The length of the list with stopwords and punctuation removed is:{len(filt_tok_2)}')
# Out:
# The length of the new filtered token with stopwords removed is: 466
# The length of the list with stopwords and punctuation removed is:376

# %%
filt_tok_2
# Out:
# ['last',
#  'month',
#  'reported',
#  'linkedin',
#  'scraping',
#  'exposed',
#  'data',
#  '700',
#  'million',
#  'users',
#  '92',
#  'service',
#  'data',
#  'included',
#  'location',
#  'phone',
#  'numbers',
#  'inferred',
#  'salaries',
#  'man',
#  'behind',
#  'identified',
#  'says',
#  'fun',
#  '”',
#  'though',
#  'also',
#  'selling',
#  'data',
#  'background',
#  'data',
#  'scraping',
#  'controversial',
#  'topic',
#  'simplest',
#  'means',
#  'writing',
#  'piece',
#  'software',
#  'visit',
#  'webpage',
#  'read',
#  'data',
#  'displayed',
#  'add',
#  'database',
#  'commonly',
#  'people',
#  'use',
#  'apis',
#  'application',
#  'programming',
#  'interfaces',
#  'provided',
#  'web',
#  'service',
#  'legitimate',
#  'purposes',
#  'use',
#  'grab',
#  'large',
#  'quantities',
#  'data',
#  '’',
#  'controversial',
#  'one',
#  'hand',
#  'scraping',
#  'argue',
#  'accessing',
#  'publicly',
#  'available',
#  'data',
#  'simply',
#  'efficient',
#  'way',
#  'others',
#  'argue',
#  'abusing',
#  'tools',
#  'intended',
#  'purpose',
#  'data',
#  'available',
#  'apis',
#  'visible',
#  'websites',
#  'making',
#  'hard',
#  'users',
#  'know',
#  'data',
#  'exposed',
#  '’',
#  'even',
#  'controversy',
#  'terminology',
#  'many',
#  'security',
#  'professionals',
#  'argue',
#  '’',
#  'security',
#  'breach',
#  'data',
#  'available',
#  'public',
#  'access',
#  'would',
#  'argue',
#  'service',
#  'like',
#  'linkedin',
#  '’',
#  'spot',
#  'someone',
#  'scraping',
#  'literally',
#  'hundreds',
#  'millions',
#  'records',
#  '’',
#  'massive',
#  'security',
#  'failing',
#  'linkedin',
#  'scraping',
#  'fun',
#  'profit',
#  'bbc',
#  'news',
#  'spoke',
#  'man',
#  'took',
#  'data',
#  'name',
#  'tom',
#  'liner',
#  'would',
#  'feel',
#  'information',
#  'catalogued',
#  'hacker',
#  'put',
#  'monster',
#  'spreadsheet',
#  'millions',
#  'entries',
#  'sold',
#  'online',
#  'highest',
#  'paying',
#  'cyber-criminal',
#  '’',
#  'hacker',
#  'calling',
#  'tom',
#  'liner',
#  'last',
#  'month',
#  'fun',
#  '”',
#  'compiled',
#  'database',
#  '700',
#  'million',
#  'linkedin',
#  'users',
#  'world',
#  'selling',
#  'around',
#  '5,000',
#  '£3,600',
#  '€4,200',
#  'case',
#  'mr',
#  'liner',
#  'latest',
#  'exploit',
#  'announced',
#  '08:57',
#  'bst',
#  'post',
#  'notorious',
#  'hacking',
#  'forum',
#  'hi',
#  '700',
#  'million',
#  '2021',
#  'linkedin',
#  'records',
#  '”',
#  'wrote',
#  'included',
#  'post',
#  'link',
#  'sample',
#  'million',
#  'records',
#  'invite',
#  'hackers',
#  'contact',
#  'privately',
#  'make',
#  'offers',
#  'database',
#  'liner',
#  'says',
#  'also',
#  'behind',
#  'scraping',
#  '533m',
#  'facebook',
#  'profiles',
#  'back',
#  'april',
#  'check',
#  'whether',
#  'data',
#  'grabbed',
#  'tom',
#  'told',
#  'created',
#  '700',
#  'million',
#  'linkedin',
#  'database',
#  'using',
#  'almost',
#  'exact',
#  'technique',
#  '”',
#  'used',
#  'create',
#  'facebook',
#  'list',
#  'said',
#  'took',
#  'several',
#  'months',
#  'complex',
#  'hack',
#  'api',
#  'linkedin',
#  'many',
#  'requests',
#  'user',
#  'data',
#  'one',
#  'time',
#  'system',
#  'permanently',
#  'ban',
#  'you.',
#  '”',
#  'linkedin',
#  'denies',
#  'liner',
#  'used',
#  'api',
#  'cybersecurity',
#  'company',
#  'sis',
#  'intelligence',
#  'says',
#  'need',
#  'controls',
#  'use',
#  'ceo',
#  'amir',
#  'hadžipašić',
#  'says',
#  'details',
#  'mass-scraping',
#  'events',
#  'people',
#  'would',
#  'expect',
#  'available',
#  'public',
#  'domain',
#  'thinks',
#  'api',
#  'programmes',
#  'give',
#  'information',
#  'users',
#  'general',
#  'public',
#  'see',
#  'tightly',
#  'controlled',
#  'large-scale',
#  'leaks',
#  'like',
#  'concerning',
#  'given',
#  'intricate',
#  'detail',
#  'cases',
#  'information',
#  'geographic',
#  'locations',
#  'private',
#  'mobile',
#  'email',
#  'addresses',
#  'people',
#  'come',
#  'surprise',
#  '’',
#  'much',
#  'information',
#  'held',
#  'api',
#  'enrichment',
#  'services',
#  'security',
#  'expert',
#  'haveibeenpwned.com',
#  'owner',
#  'troy',
#  'hunt',
#  'says',
#  '’',
#  'consider',
#  'api',
#  'misuse',
#  'security',
#  'breach',
#  'mostly',
#  'agrees',
#  'need',
#  'control',
#  '’',
#  'disagree',
#  'stance',
#  'facebook',
#  'others',
#  'feel',
#  'response',
#  '‘',
#  '’',
#  'problem',
#  '’',
#  'whilst',
#  'possibly',
#  'technically',
#  'accurate',
#  'missing',
#  'sentiment',
#  'valuable',
#  'user',
#  'data',
#  'perhaps',
#  'downplaying',
#  'roles',
#  'creation',
#  'databases.',
#  '”',
#  'photo',
#  'benjamin',
#  'lehman/unsplash',
#  'ftc',
#  'use',
#  'income',
#  'earning',
#  'auto',
#  'affiliate',
#  'links',
#  'check',
#  '9to5mac',
#  'youtube',
#  'apple',
#  'news']

# %% [markdown]
# ### Frequency distribution of words

# %%
from nltk.probability import FreqDist
fdist = FreqDist()

# %%
for word in filt_tok_2:
    fdist[word]+=1
fdist
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'scraping': 6, '”': 6, 'million': 5, 'says': 5, 'security': 5, 'liner': 5, 'api': 5, ...})

# %%
fdist['linkedin']
# Out:
# 8

# %%
fdist_top10 = fdist.most_common(10)
fdist_top10
# Out:
# [('data', 14),
#  ('’', 11),
#  ('linkedin', 8),
#  ('scraping', 6),
#  ('”', 6),
#  ('million', 5),
#  ('says', 5),
#  ('security', 5),
#  ('liner', 5),
#  ('api', 5)]

# %% [markdown]
# # Stemming / Lemmatization

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem('testing')
# Out:
# 'test'

# %%
# Creating the stems list
stems = []
[stems.append(pst.stem(filt_tok_2[idx])) for idx, key in enumerate(filt_tok_2)]

len(stems) == len(filt_tok_2)

#Creating a dictionary of word : stem
d_stems = dict(zip(filt_tok_2, stems))

d_stems
# Out:
# {'last': 'last',
#  'month': 'month',
#  'reported': 'report',
#  'linkedin': 'linkedin',
#  'scraping': 'scrape',
#  'exposed': 'expos',
#  'data': 'data',
#  '700': '700',
#  'million': 'million',
#  'users': 'user',
#  '92': '92',
#  'service': 'servic',
#  'included': 'includ',
#  'location': 'locat',
#  'phone': 'phone',
#  'numbers': 'number',
#  'inferred': 'infer',
#  'salaries': 'salari',
#  'man': 'man',
#  'behind': 'behind',
#  'identified': 'identifi',
#  'says': 'say',
#  'fun': 'fun',
#  '”': '”',
#  'though': 'though',
#  'also': 'also',
#  'selling': 'sell',
#  'background': 'background',
#  'controversial': 'controversi',
#  'topic': 'topic',
#  'simplest': 'simplest',
#  'means': 'mean',
#  'writing': 'write',
#  'piece': 'piec',
#  'software': 'softwar',
#  'visit': 'visit',
#  'webpage': 'webpag',
#  'read': 'read',
#  'displayed': 'display',
#  'add': 'add',
#  'database': 'databas',
#  'commonly': 'commonli',
#  'people': 'peopl',
#  'use': 'use',
#  'apis': 'api',
#  'application': 'applic',
#  'programming': 'program',
#  'interfaces': 'interfac',
#  'provided': 'provid',
#  'web': 'web',
#  'legitimate': 'legitim',
#  'purposes': 'purpos',
#  'grab': 'grab',
#  'large': 'larg',
#  'quantities': 'quantiti',
#  '’': '’',
#  'one': 'one',
#  'hand': 'hand',
#  'argue': 'argu',
#  'accessing': 'access',
#  'publicly': 'publicli',
#  'available': 'avail',
#  'simply': 'simpli',
#  'efficient': 'effici',
#  'way': 'way',
#  'others': 'other',
#  'abusing': 'abus',
#  'tools': 'tool',
#  'intended': 'intend',
#  'purpose': 'purpos',
#  'visible': 'visibl',
#  'websites': 'websit',
#  'making': 'make',
#  'hard': 'hard',
#  'know': 'know',
#  'even': 'even',
#  'controversy': 'controversi',
#  'terminology': 'terminolog',
#  'many': 'mani',
#  'security': 'secur',
#  'professionals': 'profession',
#  'breach': 'breach',
#  'public': 'public',
#  'access': 'access',
#  'would': 'would',
#  'like': 'like',
#  'spot': 'spot',
#  'someone': 'someon',
#  'literally': 'liter',
#  'hundreds': 'hundr',
#  'millions': 'million',
#  'records': 'record',
#  'massive': 'massiv',
#  'failing': 'fail',
#  'profit': 'profit',
#  'bbc': 'bbc',
#  'news': 'news',
#  'spoke': 'spoke',
#  'took': 'took',
#  'name': 'name',
#  'tom': 'tom',
#  'liner': 'liner',
#  'feel': 'feel',
#  'information': 'inform',
#  'catalogued': 'catalogu',
#  'hacker': 'hacker',
#  'put': 'put',
#  'monster': 'monster',
#  'spreadsheet': 'spreadsheet',
#  'entries': 'entri',
#  'sold': 'sold',
#  'online': 'onlin',
#  'highest': 'highest',
#  'paying': 'pay',
#  'cyber-criminal': 'cyber-crimin',
#  'calling': 'call',
#  'compiled': 'compil',
#  'world': 'world',
#  'around': 'around',
#  '5,000': '5,000',
#  '£3,600': '£3,600',
#  '€4,200': '€4,200',
#  'case': 'case',
#  'mr': 'mr',
#  'latest': 'latest',
#  'exploit': 'exploit',
#  'announced': 'announc',
#  '08:57': '08:57',
#  'bst': 'bst',
#  'post': 'post',
#  'notorious': 'notori',
#  'hacking': 'hack',
#  'forum': 'forum',
#  'hi': 'hi',
#  '2021': '2021',
#  'wrote': 'wrote',
#  'link': 'link',
#  'sample': 'sampl',
#  'invite': 'invit',
#  'hackers': 'hacker',
#  'contact': 'contact',
#  'privately': 'privat',
#  'make': 'make',
#  'offers': 'offer',
#  '533m': '533m',
#  'facebook': 'facebook',
#  'profiles': 'profil',
#  'back': 'back',
#  'april': 'april',
#  'check': 'check',
#  'whether': 'whether',
#  'grabbed': 'grab',
#  'told': 'told',
#  'created': 'creat',
#  'using': 'use',
#  'almost': 'almost',
#  'exact': 'exact',
#  'technique': 'techniqu',
#  'used': 'use',
#  'create': 'creat',
#  'list': 'list',
#  'said': 'said',
#  'several': 'sever',
#  'months': 'month',
#  'complex': 'complex',
#  'hack': 'hack',
#  'api': 'api',
#  'requests': 'request',
#  'user': 'user',
#  'time': 'time',
#  'system': 'system',
#  'permanently': 'perman',
#  'ban': 'ban',
#  'you.': 'you.',
#  'denies': 'deni',
#  'cybersecurity': 'cybersecur',
#  'company': 'compani',
#  'sis': 'si',
#  'intelligence': 'intellig',
#  'need': 'need',
#  'controls': 'control',
#  'ceo': 'ceo',
#  'amir': 'amir',
#  'hadžipašić': 'hadžipašić',
#  'details': 'detail',
#  'mass-scraping': 'mass-scrap',
#  'events': 'event',
#  'expect': 'expect',
#  'domain': 'domain',
#  'thinks': 'think',
#  'programmes': 'programm',
#  'give': 'give',
#  'general': 'gener',
#  'see': 'see',
#  'tightly': 'tightli',
#  'controlled': 'control',
#  'large-scale': 'large-scal',
#  'leaks': 'leak',
#  'concerning': 'concern',
#  'given': 'given',
#  'intricate': 'intric',
#  'detail': 'detail',
#  'cases': 'case',
#  'geographic': 'geograph',
#  'locations': 'locat',
#  'private': 'privat',
#  'mobile': 'mobil',
#  'email': 'email',
#  'addresses': 'address',
#  'come': 'come',
#  'surprise': 'surpris',
#  'much': 'much',
#  'held': 'held',
#  'enrichment': 'enrich',
#  'services': 'servic',
#  'expert': 'expert',
#  'haveibeenpwned.com': 'haveibeenpwned.com',
#  'owner': 'owner',
#  'troy': 'troy',
#  'hunt': 'hunt',
#  'consider': 'consid',
#  'misuse': 'misus',
#  'mostly': 'mostli',
#  'agrees': 'agre',
#  'control': 'control',
#  'disagree': 'disagre',
#  'stance': 'stanc',
#  'response': 'respons',
#  '‘': '‘',
#  'problem': 'problem',
#  'whilst': 'whilst',
#  'possibly': 'possibl',
#  'technically': 'technic',
#  'accurate': 'accur',
#  'missing': 'miss',
#  'sentiment': 'sentiment',
#  'valuable': 'valuabl',
#  'perhaps': 'perhap',
#  'downplaying': 'downplay',
#  'roles': 'role',
#  'creation': 'creation',
#  'databases.': 'databases.',
#  'photo': 'photo',
#  'benjamin': 'benjamin',
#  'lehman/unsplash': 'lehman/unsplash',
#  'ftc': 'ftc',
#  'income': 'incom',
#  'earning': 'earn',
#  'auto': 'auto',
#  'affiliate': 'affili',
#  'links': 'link',
#  '9to5mac': '9to5mac',
#  'youtube': 'youtub',
#  'apple': 'appl'}

# %%
# Finding frequency distribution of stems
fdist_stems = FreqDist()
for w in stems:
    fdist_stems[w]+=1
fdist_stems
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'million': 7, 'use': 7, 'api': 7, 'scrape': 6, 'user': 6, '”': 6, 'say': 5, ...})

# %%
fdist
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'scraping': 6, '”': 6, 'million': 5, 'says': 5, 'security': 5, 'liner': 5, 'api': 5, ...})

# %% [markdown]
# We can see some differences

# %% [markdown]
# #### Lemmatization using WordNetLemmatizer

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

# %%
word_lem = WordNetLemmatizer()
word_lem.lemmatize('salaries')
# Out:
# 'salary'

# %%
lemmas = []

[lemmas.append(word_lem.lemmatize(filt_tok_2[idx])) for idx, key in enumerate(filt_tok_2)]

len(lemmas) == len(filt_tok_2)

#Creating a dictionary of word : stem
d_lemmas = {}
d_lemmas = dict(zip(filt_tok_2, lemmas))

d_lemmas
# Out:
# {'last': 'last',
#  'month': 'month',
#  'reported': 'reported',
#  'linkedin': 'linkedin',
#  'scraping': 'scraping',
#  'exposed': 'exposed',
#  'data': 'data',
#  '700': '700',
#  'million': 'million',
#  'users': 'user',
#  '92': '92',
#  'service': 'service',
#  'included': 'included',
#  'location': 'location',
#  'phone': 'phone',
#  'numbers': 'number',
#  'inferred': 'inferred',
#  'salaries': 'salary',
#  'man': 'man',
#  'behind': 'behind',
#  'identified': 'identified',
#  'says': 'say',
#  'fun': 'fun',
#  '”': '”',
#  'though': 'though',
#  'also': 'also',
#  'selling': 'selling',
#  'background': 'background',
#  'controversial': 'controversial',
#  'topic': 'topic',
#  'simplest': 'simplest',
#  'means': 'mean',
#  'writing': 'writing',
#  'piece': 'piece',
#  'software': 'software',
#  'visit': 'visit',
#  'webpage': 'webpage',
#  'read': 'read',
#  'displayed': 'displayed',
#  'add': 'add',
#  'database': 'database',
#  'commonly': 'commonly',
#  'people': 'people',
#  'use': 'use',
#  'apis': 'apis',
#  'application': 'application',
#  'programming': 'programming',
#  'interfaces': 'interface',
#  'provided': 'provided',
#  'web': 'web',
#  'legitimate': 'legitimate',
#  'purposes': 'purpose',
#  'grab': 'grab',
#  'large': 'large',
#  'quantities': 'quantity',
#  '’': '’',
#  'one': 'one',
#  'hand': 'hand',
#  'argue': 'argue',
#  'accessing': 'accessing',
#  'publicly': 'publicly',
#  'available': 'available',
#  'simply': 'simply',
#  'efficient': 'efficient',
#  'way': 'way',
#  'others': 'others',
#  'abusing': 'abusing',
#  'tools': 'tool',
#  'intended': 'intended',
#  'purpose': 'purpose',
#  'visible': 'visible',
#  'websites': 'website',
#  'making': 'making',
#  'hard': 'hard',
#  'know': 'know',
#  'even': 'even',
#  'controversy': 'controversy',
#  'terminology': 'terminology',
#  'many': 'many',
#  'security': 'security',
#  'professionals': 'professional',
#  'breach': 'breach',
#  'public': 'public',
#  'access': 'access',
#  'would': 'would',
#  'like': 'like',
#  'spot': 'spot',
#  'someone': 'someone',
#  'literally': 'literally',
#  'hundreds': 'hundred',
#  'millions': 'million',
#  'records': 'record',
#  'massive': 'massive',
#  'failing': 'failing',
#  'profit': 'profit',
#  'bbc': 'bbc',
#  'news': 'news',
#  'spoke': 'spoke',
#  'took': 'took',
#  'name': 'name',
#  'tom': 'tom',
#  'liner': 'liner',
#  'feel': 'feel',
#  'information': 'information',
#  'catalogued': 'catalogued',
#  'hacker': 'hacker',
#  'put': 'put',
#  'monster': 'monster',
#  'spreadsheet': 'spreadsheet',
#  'entries': 'entry',
#  'sold': 'sold',
#  'online': 'online',
#  'highest': 'highest',
#  'paying': 'paying',
#  'cyber-criminal': 'cyber-criminal',
#  'calling': 'calling',
#  'compiled': 'compiled',
#  'world': 'world',
#  'around': 'around',
#  '5,000': '5,000',
#  '£3,600': '£3,600',
#  '€4,200': '€4,200',
#  'case': 'case',
#  'mr': 'mr',
#  'latest': 'latest',
#  'exploit': 'exploit',
#  'announced': 'announced',
#  '08:57': '08:57',
#  'bst': 'bst',
#  'post': 'post',
#  'notorious': 'notorious',
#  'hacking': 'hacking',
#  'forum': 'forum',
#  'hi': 'hi',
#  '2021': '2021',
#  'wrote': 'wrote',
#  'link': 'link',
#  'sample': 'sample',
#  'invite': 'invite',
#  'hackers': 'hacker',
#  'contact': 'contact',
#  'privately': 'privately',
#  'make': 'make',
#  'offers': 'offer',
#  '533m': '533m',
#  'facebook': 'facebook',
#  'profiles': 'profile',
#  'back': 'back',
#  'april': 'april',
#  'check': 'check',
#  'whether': 'whether',
#  'grabbed': 'grabbed',
#  'told': 'told',
#  'created': 'created',
#  'using': 'using',
#  'almost': 'almost',
#  'exact': 'exact',
#  'technique': 'technique',
#  'used': 'used',
#  'create': 'create',
#  'list': 'list',
#  'said': 'said',
#  'several': 'several',
#  'months': 'month',
#  'complex': 'complex',
#  'hack': 'hack',
#  'api': 'api',
#  'requests': 'request',
#  'user': 'user',
#  'time': 'time',
#  'system': 'system',
#  'permanently': 'permanently',
#  'ban': 'ban',
#  'you.': 'you.',
#  'denies': 'denies',
#  'cybersecurity': 'cybersecurity',
#  'company': 'company',
#  'sis': 'si',
#  'intelligence': 'intelligence',
#  'need': 'need',
#  'controls': 'control',
#  'ceo': 'ceo',
#  'amir': 'amir',
#  'hadžipašić': 'hadžipašić',
#  'details': 'detail',
#  'mass-scraping': 'mass-scraping',
#  'events': 'event',
#  'expect': 'expect',
#  'domain': 'domain',
#  'thinks': 'think',
#  'programmes': 'programme',
#  'give': 'give',
#  'general': 'general',
#  'see': 'see',
#  'tightly': 'tightly',
#  'controlled': 'controlled',
#  'large-scale': 'large-scale',
#  'leaks': 'leak',
#  'concerning': 'concerning',
#  'given': 'given',
#  'intricate': 'intricate',
#  'detail': 'detail',
#  'cases': 'case',
#  'geographic': 'geographic',
#  'locations': 'location',
#  'private': 'private',
#  'mobile': 'mobile',
#  'email': 'email',
#  'addresses': 'address',
#  'come': 'come',
#  'surprise': 'surprise',
#  'much': 'much',
#  'held': 'held',
#  'enrichment': 'enrichment',
#  'services': 'service',
#  'expert': 'expert',
#  'haveibeenpwned.com': 'haveibeenpwned.com',
#  'owner': 'owner',
#  'troy': 'troy',
#  'hunt': 'hunt',
#  'consider': 'consider',
#  'misuse': 'misuse',
#  'mostly': 'mostly',
#  'agrees': 'agrees',
#  'control': 'control',
#  'disagree': 'disagree',
#  'stance': 'stance',
#  'response': 'response',
#  '‘': '‘',
#  'problem': 'problem',
#  'whilst': 'whilst',
#  'possibly': 'possibly',
#  'technically': 'technically',
#  'accurate': 'accurate',
#  'missing': 'missing',
#  'sentiment': 'sentiment',
#  'valuable': 'valuable',
#  'perhaps': 'perhaps',
#  'downplaying': 'downplaying',
#  'roles': 'role',
#  'creation': 'creation',
#  'databases.': 'databases.',
#  'photo': 'photo',
#  'benjamin': 'benjamin',
#  'lehman/unsplash': 'lehman/unsplash',
#  'ftc': 'ftc',
#  'income': 'income',
#  'earning': 'earning',
#  'auto': 'auto',
#  'affiliate': 'affiliate',
#  'links': 'link',
#  '9to5mac': '9to5mac',
#  'youtube': 'youtube',
#  'apple': 'apple'}

# %%
# Finding frequency distribution of lemmas
fdist_lemmas = FreqDist()
for w in lemmas:
    fdist_lemmas[w]+=1
fdist_lemmas
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'million': 7, 'scraping': 6, 'user': 6, '”': 6, 'say': 5, 'security': 5, 'liner': 5, ...})

# %%
fdist_stems
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'million': 7, 'use': 7, 'api': 7, 'scrape': 6, 'user': 6, '”': 6, 'say': 5, ...})

# %%
fdist
# Out:
# FreqDist({'data': 14, '’': 11, 'linkedin': 8, 'scraping': 6, '”': 6, 'million': 5, 'says': 5, 'security': 5, 'liner': 5, 'api': 5, ...})

# %% [markdown]
# # POS Tagging and NER

# %%
from nltk import ne_chunk

# %%
# First we need to tag all the tokenized words
ne_tags = nltk.pos_tag(filt_tok_2)

# %%
ner = ne_chunk(ne_tags)

# %%
print(ner)
# Out:
# (S
#   last/JJ
#   month/NN
#   reported/VBD
#   linkedin/JJ
#   scraping/NN
#   exposed/VBN
#   data/NNS
#   700/CD
#   million/CD
#   users/NNS
#   92/CD
#   service/NN
#   data/NNS
#   included/VBD
#   location/NN
#   phone/NN
#   numbers/NNS
#   inferred/JJ
#   salaries/NNS
#   man/NN
#   behind/IN
#   identified/JJ
#   says/VBZ
#   fun/NN
#   ”/NNP
#   though/IN
#   also/RB
#   selling/VBG
#   data/NNS
#   background/NN
#   data/NNS
#   scraping/VBG
#   controversial/JJ
#   topic/NN
#   simplest/JJS
#   means/VBZ
#   writing/VBG
#   piece/NN
#   software/NN
#   visit/NN
#   webpage/NN
#   read/VBD
#   data/NNS
#   displayed/VBD
#   add/JJ
#   database/NN
#   commonly/RB
#   people/NNS
#   use/VBP
#   apis/JJ
#   application/NN
#   programming/VBG
#   interfaces/NNS
#   provided/VBD
#   web/JJ
#   service/NN
#   legitimate/JJ
#   purposes/NNS
#   use/VBP
#   grab/JJ
#   large/JJ
#   quantities/NNS
#   data/NNS
#   ’/RB
#   controversial/JJ
#   one/CD
#   hand/NN
#   scraping/VBG
#   argue/NN
#   accessing/VBG
#   publicly/RB
#   available/JJ
#   data/NNS
#   simply/RB
#   efficient/JJ
#   way/NN
#   others/NNS
#   argue/VBP
#   abusing/VBG
#   tools/NNS
#   intended/VBD
#   purpose/RB
#   data/NNS
#   available/JJ
#   apis/NN
#   visible/JJ
#   websites/NNS
#   making/VBG
#   hard/JJ
#   users/NNS
#   know/VBP
#   data/NNS
#   exposed/VBN
#   ’/RB
#   even/RB
#   controversy/JJ
#   terminology/NN
#   many/JJ
#   security/NN
#   professionals/NNS
#   argue/VBP
#   ’/JJ
#   security/NN
#   breach/NN
#   data/NNS
#   available/JJ
#   public/JJ
#   access/NN
#   would/MD
#   argue/VB
#   service/NN
#   like/IN
#   linkedin/JJ
#   ’/NNP
#   spot/NN
#   someone/NN
#   scraping/VBG
#   literally/RB
#   hundreds/NNS
#   millions/NNS
#   records/NNS
#   ’/VBP
#   massive/JJ
#   security/NN
#   failing/VBG
#   linkedin/NN
#   scraping/VBG
#   fun/JJ
#   profit/NN
#   bbc/NN
#   news/NN
#   spoke/VBD
#   man/NN
#   took/VBD
#   data/NNS
#   name/NN
#   tom/NN
#   liner/NN
#   would/MD
#   feel/VB
#   information/NN
#   catalogued/VBN
#   hacker/NN
#   put/VBD
#   monster/JJR
#   spreadsheet/NN
#   millions/NNS
#   entries/NNS
#   sold/VBN
#   online/JJ
#   highest/JJS
#   paying/VBG
#   cyber-criminal/JJ
#   ’/JJ
#   hacker/NN
#   calling/VBG
#   tom/NN
#   liner/NN
#   last/JJ
#   month/NN
#   fun/VBD
#   ”/NNP
#   compiled/VBD
#   database/NN
#   700/CD
#   million/CD
#   linkedin/NN
#   users/NNS
#   world/NN
#   selling/VBG
#   around/IN
#   5,000/CD
#   £3,600/NN
#   €4,200/CD
#   case/NN
#   mr/NN
#   liner/NN
#   latest/JJS
#   exploit/NN
#   announced/VBD
#   08:57/CD
#   bst/NN
#   post/NN
#   notorious/JJ
#   hacking/VBG
#   forum/NN
#   hi/$
#   700/CD
#   million/CD
#   2021/CD
#   linkedin/NN
#   records/NNS
#   ”/NNP
#   wrote/VBD
#   included/VBD
#   post/NN
#   link/NN
#   sample/NN
#   million/CD
#   records/NNS
#   invite/JJ
#   hackers/NNS
#   contact/VBP
#   privately/RB
#   make/VBP
#   offers/NNS
#   database/VB
#   liner/NN
#   says/VBZ
#   also/RB
#   behind/IN
#   scraping/VBG
#   533m/CD
#   facebook/NN
#   profiles/NNS
#   back/RB
#   april/RB
#   check/NN
#   whether/IN
#   data/NNS
#   grabbed/VBD
#   tom/JJ
#   told/RB
#   created/VBD
#   700/CD
#   million/CD
#   linkedin/JJ
#   database/NN
#   using/VBG
#   almost/RB
#   exact/JJ
#   technique/NN
#   ”/NNS
#   used/VBD
#   create/JJ
#   facebook/JJ
#   list/NN
#   said/VBD
#   took/VBD
#   several/JJ
#   months/NNS
#   complex/JJ
#   hack/NN
#   api/NN
#   linkedin/VBD
#   many/JJ
#   requests/NNS
#   user/VBP
#   data/NNS
#   one/CD
#   time/NN
#   system/NN
#   permanently/RB
#   ban/JJ
#   you./NN
#   ”/NNP
#   linkedin/NN
#   denies/VBZ
#   liner/RBR
#   used/JJ
#   api/NN
#   cybersecurity/NN
#   company/NN
#   sis/NN
#   intelligence/NN
#   says/VBZ
#   need/NN
#   controls/NNS
#   use/VBP
#   ceo/JJ
#   amir/NN
#   hadžipašić/NN
#   says/VBZ
#   details/NNS
#   mass-scraping/JJ
#   events/NNS
#   people/NNS
#   would/MD
#   expect/VB
#   available/JJ
#   public/JJ
#   domain/NN
#   thinks/NNS
#   api/VBP
#   programmes/RB
#   give/JJ
#   information/NN
#   users/NNS
#   general/JJ
#   public/JJ
#   see/VBP
#   tightly/RB
#   controlled/VBN
#   large-scale/JJ
#   leaks/NNS
#   like/IN
#   concerning/VBG
#   given/VBN
#   intricate/JJ
#   detail/NN
#   cases/NNS
#   information/NN
#   geographic/JJ
#   locations/NNS
#   private/JJ
#   mobile/JJ
#   email/NN
#   addresses/NNS
#   people/NNS
#   come/VBP
#   surprise/RB
#   ’/RB
#   much/JJ
#   information/NN
#   held/VBD
#   api/JJ
#   enrichment/NN
#   services/NNS
#   security/NN
#   expert/VBP
#   haveibeenpwned.com/NN
#   owner/NN
#   troy/NN
#   hunt/NN
#   says/VBZ
#   ’/JJ
#   consider/VB
#   api/JJ
#   misuse/NN
#   security/NN
#   breach/NN
#   mostly/RB
#   agrees/VBZ
#   need/VB
#   control/NN
#   ’/NNP
#   disagree/VBZ
#   stance/NN
#   facebook/NN
#   others/NNS
#   feel/VBP
#   response/NN
#   ‘/NN
#   ’/NN
#   problem/NN
#   ’/NNP
#   whilst/NN
#   possibly/RB
#   technically/RB
#   accurate/JJ
#   missing/VBG
#   sentiment/NN
#   valuable/JJ
#   user/NN
#   data/NNS
#   perhaps/RB
#   downplaying/VBG
#   roles/NNS
#   creation/NN
#   databases./NN
#   ”/NNP
#   photo/NN
#   benjamin/NN
#   lehman/unsplash/NN
#   ftc/NN
#   use/JJ
#   income/NN
#   earning/VBG
#   auto/NN
#   affiliate/NN
#   links/NNS
#   check/VBP
#   9to5mac/CD
#   youtube/NN
#   apple/NN
#   news/NN)

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

#Chunking
cp = nltk.RegexpParser(pattern)
cs = cp.parse(ner)
print(cs)
# Out:
# (S
#   (NP last/JJ month/NN)
#   reported/VBD
#   (NP linkedin/JJ scraping/NN)
#   exposed/VBN
#   data/NNS
#   700/CD
#   million/CD
#   users/NNS
#   92/CD
#   (NP service/NN)
#   data/NNS
#   included/VBD
#   (NP location/NN)
#   (NP phone/NN)
#   numbers/NNS
#   inferred/JJ
#   salaries/NNS
#   (NP man/NN)
#   behind/IN
#   identified/JJ
#   says/VBZ
#   (NP fun/NN)
#   ”/NNP
#   though/IN
#   also/RB
#   selling/VBG
#   data/NNS
#   (NP background/NN)
#   data/NNS
#   scraping/VBG
#   (NP controversial/JJ topic/NN)
#   simplest/JJS
#   means/VBZ
#   writing/VBG
#   (NP piece/NN)
#   (NP software/NN)
#   (NP visit/NN)
#   (NP webpage/NN)
#   read/VBD
#   data/NNS
#   displayed/VBD
#   (NP add/JJ database/NN)
#   commonly/RB
#   people/NNS
#   use/VBP
#   (NP apis/JJ application/NN)
#   programming/VBG
#   interfaces/NNS
#   provided/VBD
#   (NP web/JJ service/NN)
#   legitimate/JJ
#   purposes/NNS
#   use/VBP
#   grab/JJ
#   large/JJ
#   quantities/NNS
#   data/NNS
#   ’/RB
#   controversial/JJ
#   one/CD
#   (NP hand/NN)
#   scraping/VBG
#   (NP argue/NN)
#   accessing/VBG
#   publicly/RB
#   available/JJ
#   data/NNS
#   simply/RB
#   (NP efficient/JJ way/NN)
#   others/NNS
#   argue/VBP
#   abusing/VBG
#   tools/NNS
#   intended/VBD
#   purpose/RB
#   data/NNS
#   (NP available/JJ apis/NN)
#   visible/JJ
#   websites/NNS
#   making/VBG
#   hard/JJ
#   users/NNS
#   know/VBP
#   data/NNS
#   exposed/VBN
#   ’/RB
#   even/RB
#   (NP controversy/JJ terminology/NN)
#   (NP many/JJ security/NN)
#   professionals/NNS
#   argue/VBP
#   (NP ’/JJ security/NN)
#   (NP breach/NN)
#   data/NNS
#   (NP available/JJ public/JJ access/NN)
#   would/MD
#   argue/VB
#   (NP service/NN)
#   like/IN
#   linkedin/JJ
#   ’/NNP
#   (NP spot/NN)
#   (NP someone/NN)
#   scraping/VBG
#   literally/RB
#   hundreds/NNS
#   millions/NNS
#   records/NNS
#   ’/VBP
#   (NP massive/JJ security/NN)
#   failing/VBG
#   (NP linkedin/NN)
#   scraping/VBG
#   (NP fun/JJ profit/NN)
#   (NP bbc/NN)
#   (NP news/NN)
#   spoke/VBD
#   (NP man/NN)
#   took/VBD
#   data/NNS
#   (NP name/NN)
#   (NP tom/NN)
#   (NP liner/NN)
#   would/MD
#   feel/VB
#   (NP information/NN)
#   catalogued/VBN
#   (NP hacker/NN)
#   put/VBD
#   monster/JJR
#   (NP spreadsheet/NN)
#   millions/NNS
#   entries/NNS
#   sold/VBN
#   online/JJ
#   highest/JJS
#   paying/VBG
#   (NP cyber-criminal/JJ ’/JJ hacker/NN)
#   calling/VBG
#   (NP tom/NN)
#   (NP liner/NN)
#   (NP last/JJ month/NN)
#   fun/VBD
#   ”/NNP
#   compiled/VBD
#   (NP database/NN)
#   700/CD
#   million/CD
#   (NP linkedin/NN)
#   users/NNS
#   (NP world/NN)
#   selling/VBG
#   around/IN
#   5,000/CD
#   (NP £3,600/NN)
#   €4,200/CD
#   (NP case/NN)
#   (NP mr/NN)
#   (NP liner/NN)
#   latest/JJS
#   (NP exploit/NN)
#   announced/VBD
#   08:57/CD
#   (NP bst/NN)
#   (NP post/NN)
#   notorious/JJ
#   hacking/VBG
#   (NP forum/NN)
#   hi/$
#   700/CD
#   million/CD
#   2021/CD
#   (NP linkedin/NN)
#   records/NNS
#   ”/NNP
#   wrote/VBD
#   included/VBD
#   (NP post/NN)
#   (NP link/NN)
#   (NP sample/NN)
#   million/CD
#   records/NNS
#   invite/JJ
#   hackers/NNS
#   contact/VBP
#   privately/RB
#   make/VBP
#   offers/NNS
#   database/VB
#   (NP liner/NN)
#   says/VBZ
#   also/RB
#   behind/IN
#   scraping/VBG
#   533m/CD
#   (NP facebook/NN)
#   profiles/NNS
#   back/RB
#   april/RB
#   (NP check/NN)
#   whether/IN
#   data/NNS
#   grabbed/VBD
#   tom/JJ
#   told/RB
#   created/VBD
#   700/CD
#   million/CD
#   (NP linkedin/JJ database/NN)
#   using/VBG
#   almost/RB
#   (NP exact/JJ technique/NN)
#   ”/NNS
#   used/VBD
#   (NP create/JJ facebook/JJ list/NN)
#   said/VBD
#   took/VBD
#   several/JJ
#   months/NNS
#   (NP complex/JJ hack/NN)
#   (NP api/NN)
#   linkedin/VBD
#   many/JJ
#   requests/NNS
#   user/VBP
#   data/NNS
#   one/CD
#   (NP time/NN)
#   (NP system/NN)
#   permanently/RB
#   (NP ban/JJ you./NN)
#   ”/NNP
#   (NP linkedin/NN)
#   denies/VBZ
#   liner/RBR
#   (NP used/JJ api/NN)
#   (NP cybersecurity/NN)
#   (NP company/NN)
#   (NP sis/NN)
#   (NP intelligence/NN)
#   says/VBZ
#   (NP need/NN)
#   controls/NNS
#   use/VBP
#   (NP ceo/JJ amir/NN)
#   (NP hadžipašić/NN)
#   says/VBZ
#   details/NNS
#   mass-scraping/JJ
#   events/NNS
#   people/NNS
#   would/MD
#   expect/VB
#   (NP available/JJ public/JJ domain/NN)
#   thinks/NNS
#   api/VBP
#   programmes/RB
#   (NP give/JJ information/NN)
#   users/NNS
#   general/JJ
#   public/JJ
#   see/VBP
#   tightly/RB
#   controlled/VBN
#   large-scale/JJ
#   leaks/NNS
#   like/IN
#   concerning/VBG
#   given/VBN
#   (NP intricate/JJ detail/NN)
#   cases/NNS
#   (NP information/NN)
#   geographic/JJ
#   locations/NNS
#   (NP private/JJ mobile/JJ email/NN)
#   addresses/NNS
#   people/NNS
#   come/VBP
#   surprise/RB
#   ’/RB
#   (NP much/JJ information/NN)
#   held/VBD
#   (NP api/JJ enrichment/NN)
#   services/NNS
#   (NP security/NN)
#   expert/VBP
#   (NP haveibeenpwned.com/NN)
#   (NP owner/NN)
#   (NP troy/NN)
#   (NP hunt/NN)
#   says/VBZ
#   ’/JJ
#   consider/VB
#   (NP api/JJ misuse/NN)
#   (NP security/NN)
#   (NP breach/NN)
#   mostly/RB
#   agrees/VBZ
#   need/VB
#   (NP control/NN)
#   ’/NNP
#   disagree/VBZ
#   (NP stance/NN)
#   (NP facebook/NN)
#   others/NNS
#   feel/VBP
#   (NP response/NN)
#   (NP ‘/NN)
#   (NP ’/NN)
#   (NP problem/NN)
#   ’/NNP
#   (NP whilst/NN)
#   possibly/RB
#   technically/RB
#   accurate/JJ
#   missing/VBG
#   (NP sentiment/NN)
#   (NP valuable/JJ user/NN)
#   data/NNS
#   perhaps/RB
#   downplaying/VBG
#   roles/NNS
#   (NP creation/NN)
#   (NP databases./NN)
#   ”/NNP
#   (NP photo/NN)
#   (NP benjamin/NN)
#   (NP lehman/unsplash/NN)
#   (NP ftc/NN)
#   (NP use/JJ income/NN)
#   earning/VBG
#   (NP auto/NN)
#   (NP affiliate/NN)
#   links/NNS
#   check/VBP
#   9to5mac/CD
#   (NP youtube/NN)
#   (NP apple/NN)
#   (NP news/NN))

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('last', 'JJ', 'B-NP'),
#  ('month', 'NN', 'I-NP'),
#  ('reported', 'VBD', 'O'),
#  ('linkedin', 'JJ', 'B-NP'),
#  ('scraping', 'NN', 'I-NP'),
#  ('exposed', 'VBN', 'O'),
#  ('data', 'NNS', 'O'),
#  ('700', 'CD', 'O'),
#  ('million', 'CD', 'O'),
#  ('users', 'NNS', 'O'),
#  ('92', 'CD', 'O'),
#  ('service', 'NN', 'B-NP'),
#  ('data', 'NNS', 'O'),
#  ('included', 'VBD', 'O'),
#  ('location', 'NN', 'B-NP'),
#  ('phone', 'NN', 'B-NP'),
#  ('numbers', 'NNS', 'O'),
#  ('inferred', 'JJ', 'O'),
#  ('salaries', 'NNS', 'O'),
#  ('man', 'NN', 'B-NP'),
#  ('behind', 'IN', 'O'),
#  ('identified', 'JJ', 'O'),
#  ('says', 'VBZ', 'O'),
#  ('fun', 'NN', 'B-NP'),
#  ('”', 'NNP', 'O'),
#  ('though', 'IN', 'O'),
#  ('also', 'RB', 'O'),
#  ('selling', 'VBG', 'O'),
#  ('data', 'NNS', 'O'),
#  ('background', 'NN', 'B-NP'),
#  ('data', 'NNS', 'O'),
#  ('scraping', 'VBG', 'O'),
#  ('controversial', 'JJ', 'B-NP'),
#  ('topic', 'NN', 'I-NP'),
#  ('simplest', 'JJS', 'O'),
#  ('means', 'VBZ', 'O'),
#  ('writing', 'VBG', 'O'),
#  ('piece', 'NN', 'B-NP'),
#  ('software', 'NN', 'B-NP'),
#  ('visit', 'NN', 'B-NP'),
#  ('webpage', 'NN', 'B-NP'),
#  ('read', 'VBD', 'O'),
#  ('data', 'NNS', 'O'),
#  ('displayed', 'VBD', 'O'),
#  ('add', 'JJ', 'B-NP'),
#  ('database', 'NN', 'I-NP'),
#  ('commonly', 'RB', 'O'),
#  ('people', 'NNS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('apis', 'JJ', 'B-NP'),
#  ('application', 'NN', 'I-NP'),
#  ('programming', 'VBG', 'O'),
#  ('interfaces', 'NNS', 'O'),
#  ('provided', 'VBD', 'O'),
#  ('web', 'JJ', 'B-NP'),
#  ('service', 'NN', 'I-NP'),
#  ('legitimate', 'JJ', 'O'),
#  ('purposes', 'NNS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('grab', 'JJ', 'O'),
#  ('large', 'JJ', 'O'),
#  ('quantities', 'NNS', 'O'),
#  ('data', 'NNS', 'O'),
#  ('’', 'RB', 'O'),
#  ('controversial', 'JJ', 'O'),
#  ('one', 'CD', 'O'),
#  ('hand', 'NN', 'B-NP'),
#  ('scraping', 'VBG', 'O'),
#  ('argue', 'NN', 'B-NP'),
#  ('accessing', 'VBG', 'O'),
#  ('publicly', 'RB', 'O'),
#  ('available', 'JJ', 'O'),
#  ('data', 'NNS', 'O'),
#  ('simply', 'RB', 'O'),
#  ('efficient', 'JJ', 'B-NP'),
#  ('way', 'NN', 'I-NP'),
#  ('others', 'NNS', 'O'),
#  ('argue', 'VBP', 'O'),
#  ('abusing', 'VBG', 'O'),
#  ('tools', 'NNS', 'O'),
#  ('intended', 'VBD', 'O'),
#  ('purpose', 'RB', 'O'),
#  ('data', 'NNS', 'O'),
#  ('available', 'JJ', 'B-NP'),
#  ('apis', 'NN', 'I-NP'),
#  ('visible', 'JJ', 'O'),
#  ('websites', 'NNS', 'O'),
#  ('making', 'VBG', 'O'),
#  ('hard', 'JJ', 'O'),
#  ('users', 'NNS', 'O'),
#  ('know', 'VBP', 'O'),
#  ('data', 'NNS', 'O'),
#  ('exposed', 'VBN', 'O'),
#  ('’', 'RB', 'O'),
#  ('even', 'RB', 'O'),
#  ('controversy', 'JJ', 'B-NP'),
#  ('terminology', 'NN', 'I-NP'),
#  ('many', 'JJ', 'B-NP'),
#  ('security', 'NN', 'I-NP'),
#  ('professionals', 'NNS', 'O'),
#  ('argue', 'VBP', 'O'),
#  ('’', 'JJ', 'B-NP'),
#  ('security', 'NN', 'I-NP'),
#  ('breach', 'NN', 'B-NP'),
#  ('data', 'NNS', 'O'),
#  ('available', 'JJ', 'B-NP'),
#  ('public', 'JJ', 'I-NP'),
#  ('access', 'NN', 'I-NP'),
#  ('would', 'MD', 'O'),
#  ('argue', 'VB', 'O'),
#  ('service', 'NN', 'B-NP'),
#  ('like', 'IN', 'O'),
#  ('linkedin', 'JJ', 'O'),
#  ('’', 'NNP', 'O'),
#  ('spot', 'NN', 'B-NP'),
#  ('someone', 'NN', 'B-NP'),
#  ('scraping', 'VBG', 'O'),
#  ('literally', 'RB', 'O'),
#  ('hundreds', 'NNS', 'O'),
#  ('millions', 'NNS', 'O'),
#  ('records', 'NNS', 'O'),
#  ('’', 'VBP', 'O'),
#  ('massive', 'JJ', 'B-NP'),
#  ('security', 'NN', 'I-NP'),
#  ('failing', 'VBG', 'O'),
#  ('linkedin', 'NN', 'B-NP'),
#  ('scraping', 'VBG', 'O'),
#  ('fun', 'JJ', 'B-NP'),
#  ('profit', 'NN', 'I-NP'),
#  ('bbc', 'NN', 'B-NP'),
#  ('news', 'NN', 'B-NP'),
#  ('spoke', 'VBD', 'O'),
#  ('man', 'NN', 'B-NP'),
#  ('took', 'VBD', 'O'),
#  ('data', 'NNS', 'O'),
#  ('name', 'NN', 'B-NP'),
#  ('tom', 'NN', 'B-NP'),
#  ('liner', 'NN', 'B-NP'),
#  ('would', 'MD', 'O'),
#  ('feel', 'VB', 'O'),
#  ('information', 'NN', 'B-NP'),
#  ('catalogued', 'VBN', 'O'),
#  ('hacker', 'NN', 'B-NP'),
#  ('put', 'VBD', 'O'),
#  ('monster', 'JJR', 'O'),
#  ('spreadsheet', 'NN', 'B-NP'),
#  ('millions', 'NNS', 'O'),
#  ('entries', 'NNS', 'O'),
#  ('sold', 'VBN', 'O'),
#  ('online', 'JJ', 'O'),
#  ('highest', 'JJS', 'O'),
#  ('paying', 'VBG', 'O'),
#  ('cyber-criminal', 'JJ', 'B-NP'),
#  ('’', 'JJ', 'I-NP'),
#  ('hacker', 'NN', 'I-NP'),
#  ('calling', 'VBG', 'O'),
#  ('tom', 'NN', 'B-NP'),
#  ('liner', 'NN', 'B-NP'),
#  ('last', 'JJ', 'B-NP'),
#  ('month', 'NN', 'I-NP'),
#  ('fun', 'VBD', 'O'),
#  ('”', 'NNP', 'O'),
#  ('compiled', 'VBD', 'O'),
#  ('database', 'NN', 'B-NP'),
#  ('700', 'CD', 'O'),
#  ('million', 'CD', 'O'),
#  ('linkedin', 'NN', 'B-NP'),
#  ('users', 'NNS', 'O'),
#  ('world', 'NN', 'B-NP'),
#  ('selling', 'VBG', 'O'),
#  ('around', 'IN', 'O'),
#  ('5,000', 'CD', 'O'),
#  ('£3,600', 'NN', 'B-NP'),
#  ('€4,200', 'CD', 'O'),
#  ('case', 'NN', 'B-NP'),
#  ('mr', 'NN', 'B-NP'),
#  ('liner', 'NN', 'B-NP'),
#  ('latest', 'JJS', 'O'),
#  ('exploit', 'NN', 'B-NP'),
#  ('announced', 'VBD', 'O'),
#  ('08:57', 'CD', 'O'),
#  ('bst', 'NN', 'B-NP'),
#  ('post', 'NN', 'B-NP'),
#  ('notorious', 'JJ', 'O'),
#  ('hacking', 'VBG', 'O'),
#  ('forum', 'NN', 'B-NP'),
#  ('hi', '$', 'O'),
#  ('700', 'CD', 'O'),
#  ('million', 'CD', 'O'),
#  ('2021', 'CD', 'O'),
#  ('linkedin', 'NN', 'B-NP'),
#  ('records', 'NNS', 'O'),
#  ('”', 'NNP', 'O'),
#  ('wrote', 'VBD', 'O'),
#  ('included', 'VBD', 'O'),
#  ('post', 'NN', 'B-NP'),
#  ('link', 'NN', 'B-NP'),
#  ('sample', 'NN', 'B-NP'),
#  ('million', 'CD', 'O'),
#  ('records', 'NNS', 'O'),
#  ('invite', 'JJ', 'O'),
#  ('hackers', 'NNS', 'O'),
#  ('contact', 'VBP', 'O'),
#  ('privately', 'RB', 'O'),
#  ('make', 'VBP', 'O'),
#  ('offers', 'NNS', 'O'),
#  ('database', 'VB', 'O'),
#  ('liner', 'NN', 'B-NP'),
#  ('says', 'VBZ', 'O'),
#  ('also', 'RB', 'O'),
#  ('behind', 'IN', 'O'),
#  ('scraping', 'VBG', 'O'),
#  ('533m', 'CD', 'O'),
#  ('facebook', 'NN', 'B-NP'),
#  ('profiles', 'NNS', 'O'),
#  ('back', 'RB', 'O'),
#  ('april', 'RB', 'O'),
#  ('check', 'NN', 'B-NP'),
#  ('whether', 'IN', 'O'),
#  ('data', 'NNS', 'O'),
#  ('grabbed', 'VBD', 'O'),
#  ('tom', 'JJ', 'O'),
#  ('told', 'RB', 'O'),
#  ('created', 'VBD', 'O'),
#  ('700', 'CD', 'O'),
#  ('million', 'CD', 'O'),
#  ('linkedin', 'JJ', 'B-NP'),
#  ('database', 'NN', 'I-NP'),
#  ('using', 'VBG', 'O'),
#  ('almost', 'RB', 'O'),
#  ('exact', 'JJ', 'B-NP'),
#  ('technique', 'NN', 'I-NP'),
#  ('”', 'NNS', 'O'),
#  ('used', 'VBD', 'O'),
#  ('create', 'JJ', 'B-NP'),
#  ('facebook', 'JJ', 'I-NP'),
#  ('list', 'NN', 'I-NP'),
#  ('said', 'VBD', 'O'),
#  ('took', 'VBD', 'O'),
#  ('several', 'JJ', 'O'),
#  ('months', 'NNS', 'O'),
#  ('complex', 'JJ', 'B-NP'),
#  ('hack', 'NN', 'I-NP'),
#  ('api', 'NN', 'B-NP'),
#  ('linkedin', 'VBD', 'O'),
#  ('many', 'JJ', 'O'),
#  ('requests', 'NNS', 'O'),
#  ('user', 'VBP', 'O'),
#  ('data', 'NNS', 'O'),
#  ('one', 'CD', 'O'),
#  ('time', 'NN', 'B-NP'),
#  ('system', 'NN', 'B-NP'),
#  ('permanently', 'RB', 'O'),
#  ('ban', 'JJ', 'B-NP'),
#  ('you.', 'NN', 'I-NP'),
#  ('”', 'NNP', 'O'),
#  ('linkedin', 'NN', 'B-NP'),
#  ('denies', 'VBZ', 'O'),
#  ('liner', 'RBR', 'O'),
#  ('used', 'JJ', 'B-NP'),
#  ('api', 'NN', 'I-NP'),
#  ('cybersecurity', 'NN', 'B-NP'),
#  ('company', 'NN', 'B-NP'),
#  ('sis', 'NN', 'B-NP'),
#  ('intelligence', 'NN', 'B-NP'),
#  ('says', 'VBZ', 'O'),
#  ('need', 'NN', 'B-NP'),
#  ('controls', 'NNS', 'O'),
#  ('use', 'VBP', 'O'),
#  ('ceo', 'JJ', 'B-NP'),
#  ('amir', 'NN', 'I-NP'),
#  ('hadžipašić', 'NN', 'B-NP'),
#  ('says', 'VBZ', 'O'),
#  ('details', 'NNS', 'O'),
#  ('mass-scraping', 'JJ', 'O'),
#  ('events', 'NNS', 'O'),
#  ('people', 'NNS', 'O'),
#  ('would', 'MD', 'O'),
#  ('expect', 'VB', 'O'),
#  ('available', 'JJ', 'B-NP'),
#  ('public', 'JJ', 'I-NP'),
#  ('domain', 'NN', 'I-NP'),
#  ('thinks', 'NNS', 'O'),
#  ('api', 'VBP', 'O'),
#  ('programmes', 'RB', 'O'),
#  ('give', 'JJ', 'B-NP'),
#  ('information', 'NN', 'I-NP'),
#  ('users', 'NNS', 'O'),
#  ('general', 'JJ', 'O'),
#  ('public', 'JJ', 'O'),
#  ('see', 'VBP', 'O'),
#  ('tightly', 'RB', 'O'),
#  ('controlled', 'VBN', 'O'),
#  ('large-scale', 'JJ', 'O'),
#  ('leaks', 'NNS', 'O'),
#  ('like', 'IN', 'O'),
#  ('concerning', 'VBG', 'O'),
#  ('given', 'VBN', 'O'),
#  ('intricate', 'JJ', 'B-NP'),
#  ('detail', 'NN', 'I-NP'),
#  ('cases', 'NNS', 'O'),
#  ('information', 'NN', 'B-NP'),
#  ('geographic', 'JJ', 'O'),
#  ('locations', 'NNS', 'O'),
#  ('private', 'JJ', 'B-NP'),
#  ('mobile', 'JJ', 'I-NP'),
#  ('email', 'NN', 'I-NP'),
#  ('addresses', 'NNS', 'O'),
#  ('people', 'NNS', 'O'),
#  ('come', 'VBP', 'O'),
#  ('surprise', 'RB', 'O'),
#  ('’', 'RB', 'O'),
#  ('much', 'JJ', 'B-NP'),
#  ('information', 'NN', 'I-NP'),
#  ('held', 'VBD', 'O'),
#  ('api', 'JJ', 'B-NP'),
#  ('enrichment', 'NN', 'I-NP'),
#  ('services', 'NNS', 'O'),
#  ('security', 'NN', 'B-NP'),
#  ('expert', 'VBP', 'O'),
#  ('haveibeenpwned.com', 'NN', 'B-NP'),
#  ('owner', 'NN', 'B-NP'),
#  ('troy', 'NN', 'B-NP'),
#  ('hunt', 'NN', 'B-NP'),
#  ('says', 'VBZ', 'O'),
#  ('’', 'JJ', 'O'),
#  ('consider', 'VB', 'O'),
#  ('api', 'JJ', 'B-NP'),
#  ('misuse', 'NN', 'I-NP'),
#  ('security', 'NN', 'B-NP'),
#  ('breach', 'NN', 'B-NP'),
#  ('mostly', 'RB', 'O'),
#  ('agrees', 'VBZ', 'O'),
#  ('need', 'VB', 'O'),
#  ('control', 'NN', 'B-NP'),
#  ('’', 'NNP', 'O'),
#  ('disagree', 'VBZ', 'O'),
#  ('stance', 'NN', 'B-NP'),
#  ('facebook', 'NN', 'B-NP'),
#  ('others', 'NNS', 'O'),
#  ('feel', 'VBP', 'O'),
#  ('response', 'NN', 'B-NP'),
#  ('‘', 'NN', 'B-NP'),
#  ('’', 'NN', 'B-NP'),
#  ('problem', 'NN', 'B-NP'),
#  ('’', 'NNP', 'O'),
#  ('whilst', 'NN', 'B-NP'),
#  ('possibly', 'RB', 'O'),
#  ('technically', 'RB', 'O'),
#  ('accurate', 'JJ', 'O'),
#  ('missing', 'VBG', 'O'),
#  ('sentiment', 'NN', 'B-NP'),
#  ('valuable', 'JJ', 'B-NP'),
#  ('user', 'NN', 'I-NP'),
#  ('data', 'NNS', 'O'),
#  ('perhaps', 'RB', 'O'),
#  ('downplaying', 'VBG', 'O'),
#  ('roles', 'NNS', 'O'),
#  ('creation', 'NN', 'B-NP'),
#  ('databases.', 'NN', 'B-NP'),
#  ('”', 'NNP', 'O'),
#  ('photo', 'NN', 'B-NP'),
#  ('benjamin', 'NN', 'B-NP'),
#  ('lehman/unsplash', 'NN', 'B-NP'),
#  ('ftc', 'NN', 'B-NP'),
#  ('use', 'JJ', 'B-NP'),
#  ('income', 'NN', 'I-NP'),
#  ('earning', 'VBG', 'O'),
#  ('auto', 'NN', 'B-NP'),
#  ('affiliate', 'NN', 'B-NP'),
#  ('links', 'NNS', 'O'),
#  ('check', 'VBP', 'O'),
#  ('9to5mac', 'CD', 'O'),
#  ('youtube', 'NN', 'B-NP'),
#  ('apple', 'NN', 'B-NP'),
#  ('news', 'NN', 'B-NP')]
